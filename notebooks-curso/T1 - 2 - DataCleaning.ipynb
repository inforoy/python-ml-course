# %% [markdown]
# Data Cleaning - Análisis Preliminar de los datos
#
# Resumen de los datos: Dimensiones y estructuras

# %%
import pandas as pd
import os

# %%
fullpath = "../../python-ml-course/datasets/titanic/titanic3.csv"

# %%
data = pd.read_csv(fullpath)
data.head()

# Inicializamos los valores
data2 = data
data3 = data
data4 = data
data5 = data
data6 = data
data7 = data
data8 = data
data9 = data

# %%
# Retorna los ultimos registros
data.tail(10)

# %%
# Para conocer las cantidades de 'filas' y 'columnas'
data.shape

# %%
# Obtener el indice o la posicion
data.columns

# %%
# Se obtiene los valores en formato array (Nombre de las columnas)
data.columns.values

# %% [markdown]
# Obtener un Resumen de los estadísticos básicos de las variables numéricas

# %%
# Para conocer las estadísticas de la data
data.describe()

# %%
# Tipos de datos de las columnas
data.dtypes

# %% [markdown]
# Missing values

# %%
# Para saber si hay registros registros son "nulos", pero se debe explorar toda la data
pd.isnull(data["body"])

# %%
# Para saber si los datos son "no nulos"
pd.notnull(data["body"])

# %%
# Para sumar todos los valores 'nulos'
valore_nulos = pd.isnull(data["body"]).values.ravel().sum()
valore_nulos

# %%
# Para sumar todos los valores 'no nulos'
valores_nonulos = pd.notnull(data["body"]).values.ravel().sum()
valores_nonulos

# %%
# La suma de la cantidad de valores nulos y no nulos debe sumar el total de registros
total_registros = valore_nulos + valores_nonulos
total_registros

# %% [markdown]
# Los valores que faltan en un data set pueden venir por 2 razones:
# * Extraccion de los datos, por incompatibilidad de DB u otros
# * Recolección de los datos, cuando el usuario no registró un dato o más.

# %% [markdown]
# Borrado de valores que faltan

# %%
# Si aplicamos el siguiente comando, estaríamos eliminando todos los registros que contengan un valor 'nulo'
data.dropna(axis=0, how="all")

# %% [markdown]
# CASO 2

# %%
# Borrar cualquier registro que tenga un valor nulo (NaN)
data2.dropna(axis=0, how="any")

# %% [markdown]
# Computo de valores faltantes

# %% [markdown]
# CASO 3: DATA 3

# %%
data3

# %%
# Reemplazar todos los vampos que tengan "NaN", puede ser un numero o una cadena
# data3.fillna(0)
data3.fillna("Desconocido")

# %% [markdown]
# CASO 4: DATA 4

# %%
data4

# %%
# Llenar con ceros en la columna "body", si y solo si, esos campos son nulos
# Hacemos lo mismo con la columna "home.dest"
data4["body"] = data4["body"].fillna(0)
data4["home.dest"] = data4["home.dest"].fillna("Desconocido")
data4.head(20)

# %% [markdown]
# CASO 5: DATA 5

# %%
data5

# %%
# Contamos la cantidad de personas que no tienen edad
cantidad = pd.isnull(data5["age"]).values.ravel().sum()
print("hay ", cantidad, " personas cuya edad es nula")

# %%
# ver que el registro 1291,1292 y 1293 tienen valores nulos
print(data5["age"][1290])
print(data5["age"][1291])
print(data5["age"][1292])
print(data5["age"][1293])
print(data5["age"][1294])

# %%
# Reemplazar los valores nulos por el valor promedio o media
data5["age"] = data5["age"].fillna(data["age"].mean())

# %%
# ver resultados
print(data5["age"][1290])
print(data5["age"][1291])
print(data5["age"][1292])
print(data5["age"][1293])
print(data5["age"][1294])

# %% [markdown]
# CASO 6: DATA 6

# %%
data6

# %%
# ver que el registro 1291,1292 y 1293 tienen valores nulos
print(data6["age"][1290])
print(data6["age"][1291])
print(data6["age"][1292])
print(data6["age"][1293])
print(data6["age"][1294])

# %%
# Rellenar los nulos con el valor conocido inmediatamente anterior
data6["age"] = data6["age"].fillna(method="ffill")

# %%
# ver resultados
print(data6["age"][1290])
print(data6["age"][1291])
print(data6["age"][1292])
print(data6["age"][1293])
print(data6["age"][1294])

# %% [markdown]
# CASO 7: DATA 7

# %%
data7

# %%
# ver que el registro 1291,1292 y 1293 tienen valores nulos
print(data7["age"][1290])
print(data7["age"][1291])
print(data7["age"][1292])
print(data7["age"][1293])
print(data7["age"][1294])

# %%
# Rellenar los nulos con el primer valor conocido inmediatamente posterior
data7["age"] = data7["age"].fillna(method="backfill")

# %%
# ver que el registro 1291,1292 y 1293 tienen valores nulos
print(data7["age"][1290])
print(data7["age"][1291])
print(data7["age"][1292])
print(data7["age"][1293])
print(data7["age"][1294])

# %% [markdown]
# Variables Dummy

# %%
# ver el dato del sexo de las personas
data["sex"]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
# Crearemos una variable Dummy para crear una columna para sexo femenino y otra para el sexo masculino
dummy_sex = pd.get_dummies(data["sex"], prefix="sex")
dummy_sex
# Out:
#       sex_female  sex_male
# 0           True     False
# 1          False      True
# 2           True     False
# 3          False      True
# 4           True     False
# ...          ...       ...
# 1304        True     False
# 1305        True     False
# 1306       False      True
# 1307       False      True
# 1308       False      True
#
# [1309 rows x 2 columns]

# %% [markdown]
# # Eliminar la columna 'sex'
# # Agregar las nuevas columnas dummy de sex, 'sex_male' y 'sex_female'

# %%
# Vemos la lista de columnas
column_name = data8.columns.values.tolist()
column_name
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked',
#  'boat',
#  'body',
#  'home.dest']

# %%
# Eliminar la columna 'sex'
# axis = 1, elimina la columna
# axis = 0, elimina la fila
data8 = data8.drop(["sex"], axis=1)
data8
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %%
# Agregar las columnas Dummy al data set 
# axis = 1, para que agregue como columas
# axis = 0, para que agregue como filas
data8 = pd.concat([data8, dummy_sex], axis=1)
data8
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %% [markdown]
# Usando una funcion

# %%
def createDummies(df, var_name):
    dummy = pd.get_dummies(df[var_name], prefix = var_name)
    df = df.drop(var_name, axis = 1)
    df = pd.concat([df, dummy], axis = 1)
    return df

# %%
data9 = createDummies(data9, "sex")
data9
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...
